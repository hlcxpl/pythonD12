# %%
import pandas as pd
df = pd.read_csv('earnings.csv');
df
# Out:
#       height  weight  male     earn  earnk ethnicity  education  \
# 0         74   210.0     1  50000.0   50.0     White       16.0
# 1         66   125.0     0  60000.0   60.0     White       16.0
# 2         64   126.0     0  30000.0   30.0     White       16.0
# 3         65   200.0     0  25000.0   25.0     White       17.0
# 4         63   110.0     0  50000.0   50.0     Other       16.0
# ...      ...     ...   ...      ...    ...       ...        ...
# 1811      61   120.0     0  15000.0   15.0     White       18.0
# 1812      64   130.0     0   8000.0    8.0     White       12.0
# 1813      72   194.0     1  60000.0   60.0     White       12.0
# 1814      63   155.0     0  15000.0   15.0     Other       14.0
# 1815      68   150.0     1   6000.0    6.0     White       12.0
#
#       mother_education  father_education  walk  exercise  smokenow  tense  \
# 0                 16.0              16.0     3         3       2.0    0.0
# ...

# %%
df.dropna()
# Out:
#       height  weight  male     earn  earnk ethnicity  education  \
# 0         74   210.0     1  50000.0   50.0     White       16.0
# 1         66   125.0     0  60000.0   60.0     White       16.0
# 2         64   126.0     0  30000.0   30.0     White       16.0
# 4         63   110.0     0  50000.0   50.0     Other       16.0
# 5         68   165.0     0  62000.0   62.0     Black       18.0
# ...      ...     ...   ...      ...    ...       ...        ...
# 1811      61   120.0     0  15000.0   15.0     White       18.0
# 1812      64   130.0     0   8000.0    8.0     White       12.0
# 1813      72   194.0     1  60000.0   60.0     White       12.0
# 1814      63   155.0     0  15000.0   15.0     Other       14.0
# 1815      68   150.0     1   6000.0    6.0     White       12.0
#
#       mother_education  father_education  walk  exercise  smokenow  tense  \
# 0                 16.0              16.0     3         3       2.0    0.0
# ...

# %%
df.columns
# Out:
# Index(['height', 'weight', 'male', 'earn', 'earnk', 'ethnicity', 'education',
#        'mother_education', 'father_education', 'walk', 'exercise', 'smokenow',
#        'tense', 'angry', 'age'],
#       dtype='object')

# %%
df.drop_duplicates()
# Out:
#       height  weight  male     earn  earnk ethnicity  education  \
# 0         74   210.0     1  50000.0   50.0     White       16.0
# 1         66   125.0     0  60000.0   60.0     White       16.0
# 2         64   126.0     0  30000.0   30.0     White       16.0
# 3         65   200.0     0  25000.0   25.0     White       17.0
# 4         63   110.0     0  50000.0   50.0     Other       16.0
# ...      ...     ...   ...      ...    ...       ...        ...
# 1811      61   120.0     0  15000.0   15.0     White       18.0
# 1812      64   130.0     0   8000.0    8.0     White       12.0
# 1813      72   194.0     1  60000.0   60.0     White       12.0
# 1814      63   155.0     0  15000.0   15.0     Other       14.0
# 1815      68   150.0     1   6000.0    6.0     White       12.0
#
#       mother_education  father_education  walk  exercise  smokenow  tense  \
# 0                 16.0              16.0     3         3       2.0    0.0
# ...

# %%
import numpy as np
import scipy.stats as stats

earn_data= df['earn']
height_data =df['height']
age_data = df['age']

# Función para realizar las pruebas de hipótesis
def realizar_prueba_hipotesis(data, H0, alternativa, nivel_confianza):
    muestra = np.random.choice(data, size=25, replace=False)
    if alternativa == '=':
        p_valor = stats.ttest_1samp(muestra, H0)[1]
    elif alternativa == '!=':
        _, p_valor = stats.ttest_1samp(muestra, H0)
    elif alternativa == '>':
        _, p_valor = stats.ttest_1samp(muestra, H0, alternative='greater')
    elif alternativa == '<':
        _, p_valor = stats.ttest_1samp(muestra, H0, alternative='less')
    
    if p_valor < nivel_confianza:
        resultado = f"con nivel de confianza del {(1 - nivel_confianza) * 100}%, se rechaza la hipótesis nula"
    else:
        resultado = f"con nivel de confianza del {(1 - nivel_confianza) * 100}%, se acepta la hipótesis nula"
    return resultado

# Especificaciones para las pruebas de hipótesis
pruebas_earn = [(20000, '!='), (35000, '!='), (25000, '>'), (32000, '<')]
pruebas_height = [(55, '='), (68, '!='), (63, '>'), (70, '<')]
pruebas_age = [(44, '!='), (56, '!='), (51, '>'), (62, '<')]

# Realizar las pruebas de hipótesis para earn
print("Resultados para earn:")
for H0, alternativa in pruebas_earn:
    resultado = realizar_prueba_hipotesis(earn_data, H0, alternativa, 0.1)
    print(f"H0: x {alternativa} {H0} - {resultado}")

# Realizar las pruebas de hipótesis para height
print("Resultados para height:")
for H0, alternativa in pruebas_height:
    resultado = realizar_prueba_hipotesis(height_data, H0, alternativa, 0.1)
    print(f"H0: x {alternativa} {H0} - {resultado}")

# Realizar las pruebas de hipótesis para age
print("Resultados para age:")
for H0, alternativa in pruebas_age:
    resultado = realizar_prueba_hipotesis(age_data, H0, alternativa, 0.1)
    print(f"H0: x {alternativa} {H0} - {resultado}")
# Out:
# Resultados para earn:
# H0: x != 20000 - con nivel de confianza del 90.0%, se acepta la hipótesis nula
# H0: x != 35000 - con nivel de confianza del 90.0%, se rechaza la hipótesis nula
# H0: x > 25000 - con nivel de confianza del 90.0%, se acepta la hipótesis nula
# H0: x < 32000 - con nivel de confianza del 90.0%, se acepta la hipótesis nula
# Resultados para height:
# H0: x = 55 - con nivel de confianza del 90.0%, se rechaza la hipótesis nula
# H0: x != 68 - con nivel de confianza del 90.0%, se acepta la hipótesis nula
# H0: x > 63 - con nivel de confianza del 90.0%, se rechaza la hipótesis nula
# H0: x < 70 - con nivel de confianza del 90.0%, se rechaza la hipótesis nula
# Resultados para age:
# H0: x != 44 - con nivel de confianza del 90.0%, se acepta la hipótesis nula
# H0: x != 56 - con nivel de confianza del 90.0%, se rechaza la hipótesis nula
# H0: x > 51 - con nivel de confianza del 90.0%, se acepta la hipótesis nula
# ...

# %%
# Calcular la media poblacional para earn, height y age
media_earn = df['earn'].mean()
media_height = df['height'].mean()
media_age = df['age'].mean()

# Mostrar los resultados
print(f"Media poblacional para earn: {media_earn}")
print(f"Media poblacional para height: {media_height}")
print(f"Media poblacional para age: {media_age}")
# Out:
# Media poblacional para earn: 21147.296255506608
# Media poblacional para height: 66.56883259911895
# Media poblacional para age: 42.934471365638764

# %% [markdown]
# **Para earn:**
#
# - La hipótesis nula \(H_0: \mu \neq 20000\) se acepta con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu \neq 35000\) se rechaza con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu > 25000\) se acepta con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu < 32000\) se acepta con un nivel de confianza del 90%.
#
# **Para height:**
#
# - La hipótesis nula \(H_0: \mu = 55\) se rechaza con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu \neq 68\) se acepta con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu > 63\) se rechaza con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu < 70\) se rechaza con un nivel de confianza del 90%.
#
# **Para age:**
#
# - La hipótesis nula \(H_0: \mu \neq 44\) se acepta con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu \neq 56\) se rechaza con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu > 51\) se acepta con un nivel de confianza del 90%.
# - La hipótesis nula \(H_0: \mu < 62\) se rechaza con un nivel de confianza del 90%.
#
# Estos resultados indican las decisiones tomadas respecto a las hipótesis nulas planteadas para cada variable con un nivel de confianza del 90%.

# %%
def estimar_proporcion_hombres(data, muestra_size=50, nivel_confianza=0.05):
    muestra = np.random.choice(data, size=muestra_size, replace=False)
    proporcion_muestra = np.mean(muestra)
    
    _, p_valor = stats.ttest_1samp(muestra, 0.5)  # Comparar con la proporción real de hombres (0.5)
    
    if p_valor < nivel_confianza:
        resultado = f"El p-valor ({p_valor}) es menor que el nivel de confianza del {nivel_confianza * 100}%, por lo tanto, se rechaza la hipótesis nula. La proporción estimada de hombres en la muestra es {proporcion_muestra}."
    else:
        resultado = f"El p-valor ({p_valor}) es mayor que el nivel de confianza del {nivel_confianza * 100}%, por lo tanto, no hay suficiente evidencia para rechazar la hipótesis nula. La proporción estimada de hombres en la muestra es {proporcion_muestra}."
    
    return resultado

# Ejemplo de uso con la columna 'male' del DataFrame
proporcion_real = df['male'].mean()  # Proporción real de hombres en el dataset
resultado_05 = estimar_proporcion_hombres(df['male'], nivel_confianza=0.05)
resultado_01 = estimar_proporcion_hombres(df['male'], nivel_confianza=0.01)

print("Proporción real de hombres en el dataset:", proporcion_real)
print("Resultado para nivel de significancia 0.05:", resultado_05)
print("Resultado para nivel de significancia 0.01:", resultado_01)
# Out:
# Proporción real de hombres en el dataset: 0.3716960352422907
# Resultado para nivel de significancia 0.05: El p-valor (0.5768126908825979) es mayor que el nivel de confianza del 5.0%, por lo tanto, no hay suficiente evidencia para rechazar la hipótesis nula. La proporción estimada de hombres en la muestra es 0.54.
# Resultado para nivel de significancia 0.01: El p-valor (0.022070032009030773) es mayor que el nivel de confianza del 1.0%, por lo tanto, no hay suficiente evidencia para rechazar la hipótesis nula. La proporción estimada de hombres en la muestra es 0.34.

# %%
# Separar los salarios de hombres y mujeres en dos grupos
earn_hombres = df[df['male'] == 1]['earn']
earn_mujeres = df[df['male'] == 0]['earn']

# Realizar una prueba t para dos muestras independientes
t_stat, p_valor = stats.ttest_ind(earn_hombres, earn_mujeres)

# Establecer el nivel de significancia
nivel_confianza = 0.05

# Comparar el p-valor con el nivel de significancia
if p_valor < nivel_confianza:
    resultado = f"El p-valor ({p_valor}) es menor que el nivel de significancia del {nivel_confianza * 100}%, por lo tanto, se rechaza la hipótesis nula. Existe evidencia estadística para decir que el género influye en el sueldo de las personas en este dataset."
else:
    resultado = f"El p-valor ({p_valor}) es mayor que el nivel de significancia del {nivel_confianza * 100}%, por lo tanto, no hay suficiente evidencia para rechazar la hipótesis nula. No se puede concluir que el género influye en el sueldo de las personas en este dataset."

print(resultado)
# Out:
# El p-valor (1.2371946179054943e-40) es menor que el nivel de significancia del 5.0%, por lo tanto, se rechaza la hipótesis nula. Existe evidencia estadística para decir que el género influye en el sueldo de las personas en este dataset.
